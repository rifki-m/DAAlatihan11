# %%
# T----U----V
# /         /
# W---------X
# /         /
# Z         S

# %%
graph = {
    "T" : ["U","W"],
    "U" : ["T","V"],
    "V" : ["U","X"],
    "W" : ["T","X","Z"],
    "X" : ["V","W","S"],
    "Z" : ["W"],
    "S" : ["X"]
}
print(graph)
# Out:
# {'T': ['U', 'W'], 'U': ['T', 'V'], 'V': ['U', 'X'], 'W': ['T', 'X', 'Z'], 'X': ['V', 'W', 'S'], 'Z': ['W'], 'S': ['X']}

# %%
#Simpul GRAPH TUV
class Graph:
    def __init__(self,gdict=None):
        if gdict is None:
            gdict = []
        self.gdict = gdict

    def getVertices(self):
        return list(self.gdict.keys())

graph_elements = {
    "T" : ["U","W"],
    "U" : ["T","V"],
    "V" : ["U","X"],
    "W" : ["T","X","Z"],
    "X" : ["V","W","S"],
    "Z" : ["W"],
    "S" : ["X"]
 }


g = Graph(graph_elements)

print(g.getVertices())
# Out:
# ['T', 'U', 'V', 'W', 'X', 'Z', 'S']

# %%
#edge GRAPH TUV
class Graph:
    def __init__(self,gdict=None):
        if gdict is None:
            gdict = {}
        self.gdict = gdict

    def edges(self):
        return self.findedges()

    def findedges(self):
        edgename = []
        for vrtx in self.gdict:
            for nxtvrtx in self.gdict[vrtx]:
                if {nxtvrtx, vrtx} not in edgename:
                    edgename.append({vrtx, nxtvrtx})
        return edgename

graph_elements = {
                "T" : ["U","W"],
                "U" : ["T","V"],
                "V" : ["U","X"],
                "W" : ["T","X","Z"],
                "X" : ["V","W","S"],
                "Z" : ["W"],
                "S" : ["X"]
                }

g = Graph(graph_elements)

print(g.edges())
# Out:
# [{'U', 'T'}, {'T', 'W'}, {'U', 'V'}, {'X', 'V'}, {'X', 'W'}, {'Z', 'W'}, {'X', 'S'}]

# %%
#Menambahkan Simpul R GRAPH TUV
class Graph:
    def __init__(self,gdict=None):
        if gdict is None:
            gdict = []
        self.gdict = gdict

    def getVertices(self):
        return list(self.gdict.keys())

    def addVertex(self, vrtx):
        if vrtx not in self.gdict:
            self.gdict[vrtx] = []

graph_elements = {
    "T" : ["U","W"],
    "U" : ["T","V"],
    "V" : ["U","X"],
    "W" : ["T","X","Z"],
    "X" : ["V","W","S"],
    "Z" : ["W"],
    "S" : ["X"]
 }

g = Graph(graph_elements)

g.addVertex("R")

print(g.getVertices())
# Out:
# ['T', 'U', 'V', 'W', 'X', 'Z', 'S', 'R']

# %%
# r----o----m
# /    /    /
# i----p----n

# %%
graph = {
    "r" : ["o","i"],
    "o" : ["r","m"],
    "m" : ["o","n"],
    "i" : ["r","p"],
    "p" : ["i","n"],
    "n" : ["p","m"]
}
print(graph)
# Out:
# {'r': ['o', 'i'], 'o': ['r', 'm'], 'm': ['o', 'n'], 'i': ['r', 'p'], 'p': ['i', 'n'], 'n': ['p', 'm']}

# %%
#Simpul GRAPH ROM
class Graph:
    def __init__(self,gdict=None):
        if gdict is None:
            gdict = []
        self.gdict = gdict

        # Get the keys of the dictionary
    def getVertices(self):
        return list(self.gdict.keys())

graph_elements = {
    "r" : ["o","i"],
    "o" : ["r","m"],
    "m" : ["o","n"],
    "i" : ["r","p"],
    "p" : ["i","n"],
    "n" : ["p","m"]
}

g = Graph(graph_elements)

print(g.getVertices())
# Out:
# ['r', 'o', 'm', 'i', 'p', 'n']

# %%
#edge GRAPH ROM
class graph:
    def __init__(self,gdict=None):
        if gdict is None:
            gdict = {}
        self.gdict = gdict

    def edges(self):
        return self.findedges()

    def findedges(self):
        edgename = []
        for vrtx in self.gdict:
            for nxtvrtx in self.gdict[vrtx]:
                if {nxtvrtx, vrtx} not in edgename:
                    edgename.append({vrtx, nxtvrtx})
        return edgename

graph_elements = { "r" : ["o","i"],
                "o" : ["r","m"],
                "m" : ["o","n"],
                "i" : ["r","p"],
                "p" : ["i","n"],
                "n" : ["p","m"]
      }

g = graph(graph_elements)

print(g.edges())
# Out:
# [{'r', 'o'}, {'i', 'r'}, {'m', 'o'}, {'n', 'm'}, {'i', 'p'}, {'p', 'n'}]

# %%
#Menambahkan Simpul
#Simpul GRAPH ROM
class Graph:
    def __init__(self,gdict=None):
        if gdict is None:
            gdict = []
        self.gdict = gdict

    def getVertices(self):
        return list(self.gdict.keys())

    def addVertex(self, vrtx):
        if vrtx not in self.gdict:
            self.gdict[vrtx] = []

graph_elements = {
        "r" : ["o","i"],
        "o" : ["r","m"],
        "m" : ["o","n"],
        "i" : ["r","p"],
                "p" : ["i","n"],
                "n" : ["p","m"]
 }

g = Graph(graph_elements)

g.addVertex("K")
g.addVertex("J")

print(g.getVertices())
# Out:
# ['r', 'o', 'm', 'i', 'p', 'n', 'K', 'J']
